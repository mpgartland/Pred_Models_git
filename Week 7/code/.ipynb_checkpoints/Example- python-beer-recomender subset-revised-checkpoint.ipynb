# %% [markdown]
# Building a Recommendation System in Python
# ============================
# > In this tutorial we'll show you how to build a recommendation system using pandas, scikit-learn, and numpy. We've provided a dataset of beer reviews which we'll use for building our product recommender, but this use case could be easily substituted with a different product.

# %%
import pandas as pd
import numpy as np
import pylab as pl
import matplotlib.pyplot as plt

# %% [markdown]
# <h2><a href="https://s3.amazonaws.com/demo-datasets/beer_reviews.tar.gz">Download the data</a></h2>
# <p>Grab the dataset from our data demos bucket on S3, then decompress it. It will create a directory called ~/Downloads/beer_reviews.</p>

# %%
cd /Users/mylesgartland/OneDrive - Rockhurst University/Courses/Predictive Models
# Out:
# /Users/mylesgartland/OneDrive - Rockhurst University/Courses/Predictive Models

# %%
# substitute your name here. If you're on windows you'll need a different filepath
df = pd.read_csv("beer_reviews.csv", encoding='iso-8859-1')
df.head(150)
# Out:
#      brewery_id             brewery_name  review_time  review_overall  \
# 0         10325          Vecchio Birraio   1234817823             1.5
# 1         10325          Vecchio Birraio   1235915097             3.0
# 2         10325          Vecchio Birraio   1235916604             3.0
# 3         10325          Vecchio Birraio   1234725145             3.0
# 4          1075  Caldera Brewing Company   1293735206             4.0
# 5          1075  Caldera Brewing Company   1325524659             3.0
# 6          1075  Caldera Brewing Company   1318991115             3.5
# 7          1075  Caldera Brewing Company   1306276018             3.0
# 8          1075  Caldera Brewing Company   1290454503             4.0
# 9          1075  Caldera Brewing Company   1285632924             4.5
# 10          163   Amstel Brouwerij B. V.   1010963392             3.0
# 11         1075  Caldera Brewing Company   1283154365             5.0
# 12         1075  Caldera Brewing Company   1277557990             4.0
# 13         1075  Caldera Brewing Company   1275779250             4.0
# 14         1075  Caldera Brewing Company   1273109020             3.5
# 15         1075  Caldera Brewing Company   1316025612             3.0
# 16         1075  Caldera Brewing Company   1103502339             2.0
# 17         1075  Caldera Brewing Company   1062311123             4.0
# 18          163   Amstel Brouwerij B. V.   1010861086             2.5
# 19         1075  Caldera Brewing Company   1325478004             4.5
# 20         1075  Caldera Brewing Company   1325360812             4.0
# 21         1075  Caldera Brewing Company   1322506304             4.0
# 22         1075  Caldera Brewing Company   1320494397             4.5
# 23         1075  Caldera Brewing Company   1320140421             4.0
# 24         1075  Caldera Brewing Company   1319847514             4.5
# 25         1075  Caldera Brewing Company   1318802642             5.0
# 26         1075  Caldera Brewing Company   1318290101             4.5
# 27         1075  Caldera Brewing Company   1318289482             4.5
# 28         1075  Caldera Brewing Company   1316405909             4.5
# 29         1075  Caldera Brewing Company   1315696563             4.5
# ..          ...                      ...          ...             ...
# 120        1075  Caldera Brewing Company   1204256003             4.0
# 121        1075  Caldera Brewing Company   1199158664             3.0
# 122        1075  Caldera Brewing Company   1198817492             3.0
# 123        1075  Caldera Brewing Company   1190043490             4.5
# 124        1075  Caldera Brewing Company   1188970905             4.5
# 125        1075  Caldera Brewing Company   1186867975             4.0
# 126        1075  Caldera Brewing Company   1275439462             4.0
# 127        1075  Caldera Brewing Company   1182308568             4.0
# 128        1075  Caldera Brewing Company   1181450867             4.5
# 129        1075  Caldera Brewing Company   1177638920             4.0
# 130        1075  Caldera Brewing Company   1170714306             4.5
# 131        1075  Caldera Brewing Company   1160699043             5.0
# 132        1075  Caldera Brewing Company   1160265839             3.5
# 133        1075  Caldera Brewing Company   1157665307             4.0
# 134        1075  Caldera Brewing Company   1154568582             4.5
# 135        1075  Caldera Brewing Company   1154067787             4.5
# 136        1075  Caldera Brewing Company   1148947298             3.0
# 137        1075  Caldera Brewing Company   1147643598             4.0
# 138        1075  Caldera Brewing Company   1147583357             4.0
# 139        1075  Caldera Brewing Company   1132082651             4.5
# 140        1075  Caldera Brewing Company   1124731747             4.0
# 141        1075  Caldera Brewing Company   1326212716             4.0
# 142        1075  Caldera Brewing Company   1322517349             3.5
# 143        1075  Caldera Brewing Company   1321322911             4.0
# 144        1075  Caldera Brewing Company   1274928281             4.0
# 145        1075  Caldera Brewing Company   1320470970             3.5
# 146        1075  Caldera Brewing Company   1320422191             4.0
# 147        1075  Caldera Brewing Company   1318247779             3.0
# 148        1075  Caldera Brewing Company   1316727048             4.0
# 149        1075  Caldera Brewing Company   1315501843             4.0
#
#      review_aroma  review_appearance review_profilename  \
# 0             2.0                2.5            stcules
# 1             2.5                3.0            stcules
# 2             2.5                3.0            stcules
# 3             3.0                3.5            stcules
# 4             4.5                4.0     johnmichaelsen
# 5             3.5                3.5            oline73
# 6             3.5                3.5          Reidrover
# 7             2.5                3.5       alpinebryant
# 8             3.0                3.5      LordAdmNelson
# 9             3.5                5.0       augustgarage
# 10            2.0                3.0            fodeeoz
# 11            5.0                4.0       MadeInOregon
# 12            4.0                4.0            rawthar
# 13            4.5                3.0        Halcyondays
# 14            4.0                3.0        RangerClegg
# 15            3.0                2.5   Beerandraiderfan
# 16            1.5                2.5         RedDiamond
# 17            3.0                4.0         beerguy101
# 18            3.0                3.0             jdhilt
# 19            4.5                3.0        UCLABrewN84
# 20            4.0                4.0         zaphodchak
# 21            4.5                4.0            Tilley4
# 22            5.0                4.5    mikedrinksbeer2
# 23            4.5                4.0         dbmernin83
# 24            4.5                4.0     titosupertramp
# 25            5.0                3.5        optimator13
# 26            4.5                4.0          Blakaeris
# 27            5.0                4.0            bashiba
# 28            4.5                3.5               Klym
# 29            4.5                4.0          flexabull
# ..            ...                ...                ...
# 120           3.5                4.0          Spikester
# 121           2.5                3.0         Dubbercody
# 122           4.0                3.5       ChainGangGuy
# 123           4.0                4.5             Vancer
# 124           3.5                3.5        ghostwalker
# 125           4.0                4.5           udubdawg
# 126           3.5                2.5              Bfarr
# 127           4.0                4.0            cburian
# 128           4.0                4.0          flexabull
# 129           3.0                3.5             mnwags
# 130           4.0                3.5        NeroFiddled
# 131           4.0                3.5          IntriqKen
# 132           4.0                3.0              JoshD
# 133           3.5                4.0       lackenhauser
# 134           4.0                4.0           kgotcher
# 135           4.0                3.0          MLegendre
# 136           4.0                4.0              freed
# 137           4.0                3.5            ddarden
# 138           4.0                3.5            ElGordo
# 139           4.5                4.5      BuckeyeNation
# 140           3.5                4.0          Reidrover
# 141           4.0                4.0        BeerLover99
# 142           4.0                3.5           syrupjoe
# 143           4.5                4.0            BrewerB
# 144           4.0                3.5        robwestcott
# 145           3.5                4.5              vande
# 146           3.5                4.0        ColForbinBC
# 147           2.5                3.5           harrymel
# 148           3.5                4.5        woosterbill
# 149           4.0                4.5     ReelBigwigFish
#
#                          beer_style  review_palate  review_taste  \
# 0                        Hefeweizen            1.5           1.5
# 1                English Strong Ale            3.0           3.0
# 2            Foreign / Export Stout            3.0           3.0
# 3                   German Pilsener            2.5           3.0
# 4    American Double / Imperial IPA            4.0           4.5
# 5              Herbed / Spiced Beer            3.0           3.5
# 6              Herbed / Spiced Beer            4.0           4.0
# 7              Herbed / Spiced Beer            2.0           3.5
# 8              Herbed / Spiced Beer            3.5           4.0
# 9              Herbed / Spiced Beer            4.0           4.0
# 10                      Light Lager            2.5           2.5
# 11             Herbed / Spiced Beer            4.0           4.0
# 12             Herbed / Spiced Beer            3.5           4.0
# 13             Herbed / Spiced Beer            2.5           3.0
# 14             Herbed / Spiced Beer            3.0           4.0
# 15                    Oatmeal Stout            3.0           3.0
# 16                    Oatmeal Stout            2.5           2.0
# 17              American Pale Lager            4.0           4.0
# 18                      Light Lager            2.0           2.0
# 19                        Rauchbier            4.0           4.5
# 20                        Rauchbier            3.0           4.0
# 21                        Rauchbier            3.5           4.0
# 22                        Rauchbier            4.0           4.5
# 23                        Rauchbier            4.0           4.5
# 24                        Rauchbier            4.0           4.5
# 25                        Rauchbier            3.5           5.0
# 26                        Rauchbier            4.0           4.5
# 27                        Rauchbier            4.0           4.0
# 28                        Rauchbier            4.0           4.5
# 29                        Rauchbier            4.0           4.0
# ..                              ...            ...           ...
# 120         American Pale Ale (APA)            3.0           4.0
# 121         American Pale Ale (APA)            3.0           3.0
# 122         American Pale Ale (APA)            3.5           3.0
# 123         American Pale Ale (APA)            4.5           4.0
# 124         American Pale Ale (APA)            3.5           4.0
# 125         American Pale Ale (APA)            4.0           4.0
# 126         American Pale Ale (APA)            3.0           4.5
# 127         American Pale Ale (APA)            4.0           4.5
# 128         American Pale Ale (APA)            3.5           4.0
# 129         American Pale Ale (APA)            2.5           3.5
# 130         American Pale Ale (APA)            4.5           4.0
# 131         American Pale Ale (APA)            4.0           4.0
# 132         American Pale Ale (APA)            3.5           3.0
# 133         American Pale Ale (APA)            4.0           4.0
# 134         American Pale Ale (APA)            4.0           4.0
# 135         American Pale Ale (APA)            3.5           4.0
# 136         American Pale Ale (APA)            3.0           3.0
# 137         American Pale Ale (APA)            4.0           4.0
# 138         American Pale Ale (APA)            4.0           3.5
# 139         American Pale Ale (APA)            4.0           4.0
# 140         American Pale Ale (APA)            3.5           4.0
# 141         American Pale Ale (APA)            4.0           4.0
# 142         American Pale Ale (APA)            4.0           3.5
# 143         American Pale Ale (APA)            4.5           4.0
# 144         American Pale Ale (APA)            4.0           3.5
# 145         American Pale Ale (APA)            4.0           3.0
# 146         American Pale Ale (APA)            3.5           4.0
# 147         American Pale Ale (APA)            3.5           3.0
# 148         American Pale Ale (APA)            3.5           4.0
# 149         American Pale Ale (APA)            4.0           4.0
#
#                   beer_name  beer_abv  beer_beerid
# 0              Sausa Weizen       5.0        47986
# 1                  Red Moon       6.2        48213
# 2    Black Horse Black Beer       6.5        48215
# 3                Sausa Pils       5.0        47969
# 4             Cauldron DIPA       7.7        64883
# 5       Caldera Ginger Beer       4.7        52159
# 6       Caldera Ginger Beer       4.7        52159
# 7       Caldera Ginger Beer       4.7        52159
# 8       Caldera Ginger Beer       4.7        52159
# 9       Caldera Ginger Beer       4.7        52159
# 10             Amstel Light       3.5          436
# 11      Caldera Ginger Beer       4.7        52159
# 12      Caldera Ginger Beer       4.7        52159
# 13      Caldera Ginger Beer       4.7        52159
# 14      Caldera Ginger Beer       4.7        52159
# 15    Caldera Oatmeal Stout       7.2        10789
# 16    Caldera Oatmeal Stout       7.2        10789
# 17           Caldera OBF 15       5.6        12386
# 18             Amstel Light       3.5          436
# 19           Rauch Ãr Bock       7.4        58046
# 20           Rauch Ãr Bock       7.4        58046
# 21           Rauch Ãr Bock       7.4        58046
# 22           Rauch Ãr Bock       7.4        58046
# 23           Rauch Ãr Bock       7.4        58046
# 24           Rauch Ãr Bock       7.4        58046
# 25           Rauch Ãr Bock       7.4        58046
# 26           Rauch Ãr Bock       7.4        58046
# 27           Rauch Ãr Bock       7.4        58046
# 28           Rauch Ãr Bock       7.4        58046
# 29           Rauch Ãr Bock       7.4        58046
# ..                      ...       ...          ...
# 120        Caldera Pale Ale       5.5        25414
# 121        Caldera Pale Ale       5.5        25414
# 122        Caldera Pale Ale       5.5        25414
# 123        Caldera Pale Ale       5.5        25414
# 124        Caldera Pale Ale       5.5        25414
# 125        Caldera Pale Ale       5.5        25414
# 126        Caldera Pale Ale       5.5        25414
# 127        Caldera Pale Ale       5.5        25414
# 128        Caldera Pale Ale       5.5        25414
# 129        Caldera Pale Ale       5.5        25414
# 130        Caldera Pale Ale       5.5        25414
# 131        Caldera Pale Ale       5.5        25414
# 132        Caldera Pale Ale       5.5        25414
# 133        Caldera Pale Ale       5.5        25414
# 134        Caldera Pale Ale       5.5        25414
# 135        Caldera Pale Ale       5.5        25414
# 136        Caldera Pale Ale       5.5        25414
# 137        Caldera Pale Ale       5.5        25414
# 138        Caldera Pale Ale       5.5        25414
# 139        Caldera Pale Ale       5.5        25414
# 140        Caldera Pale Ale       5.5        25414
# 141        Caldera Pale Ale       5.5        25414
# 142        Caldera Pale Ale       5.5        25414
# 143        Caldera Pale Ale       5.5        25414
# 144        Caldera Pale Ale       5.5        25414
# 145        Caldera Pale Ale       5.5        25414
# 146        Caldera Pale Ale       5.5        25414
# 147        Caldera Pale Ale       5.5        25414
# 148        Caldera Pale Ale       5.5        25414
# 149        Caldera Pale Ale       5.5        25414
#
# [150 rows x 13 columns]

# %%
df.shape
# Out:
# (1586614, 13)

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Check for and remove nulls

# %%
df.isnull().sum()
# Out:
# brewery_id            0
# brewery_name          0
# review_time           0
# review_overall        0
# review_aroma          0
# review_appearance     0
# review_profilename    0
# beer_style            0
# review_palate         0
# review_taste          0
# beer_name             0
# beer_abv              0
# beer_beerid           0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# brewery_id            0
# brewery_name          0
# review_time           0
# review_overall        0
# review_aroma          0
# review_appearance     0
# review_profilename    0
# beer_style            0
# review_palate         0
# review_taste          0
# beer_name             0
# beer_abv              0
# beer_beerid           0
# dtype: int64

# %%
dtype_df = df.dtypes.reset_index()
dtype_df.columns = ["Count", "Column Type"]
dtype_df
dtype_df.groupby("Column Type").aggregate('count').reset_index()
# Out:
#   Column Type  Count
# 0       int64      3
# 1     float64      6
# 2      object      4

# %%
for attName in df.columns:
    dType = df[attName].dtype
    if (df[attName].dtype == float or df[attName].dtype == int):
        df[attName].fillna(df[attName].mean(), inplace=True)

# %% [markdown]
# ## Finding People Who Have Reviewed 2 Beers

# %%
beer_1, beer_2 = "Dale's Pale Ale", "Fat Tire Amber Ale"

beer_1_reviewers = df[df.beer_name==beer_1].review_profilename.unique()
beer_2_reviewers = df[df.beer_name==beer_2].review_profilename.unique()
common_reviewers = set(beer_1_reviewers).intersection(beer_2_reviewers)
print("Users in the sameset: %d"), len(common_reviewers)
list(common_reviewers)[:10]
# Out:
# Users in the sameset: %d
# ['Samp01',
#  'kawilliams81',
#  'beveritt',
#  'LiquidBread219',
#  'Beefeater57',
#  'BerkeleyBeerMan',
#  'BWMKappaSig',
#  'CraftBeerTastic',
#  'prototypic',
#  'Proteus93']

# %% [markdown]
# ## Extracting Reviews

# %%
beer_1, beer_2 = "Samuel Adams Octoberfest", "Caldera Ginger Beer"

beer_1_reviewers = df[df.beer_name==beer_1].review_profilename.unique()
beer_2_reviewers = df[df.beer_name==beer_2].review_profilename.unique()
common_reviewers = set(beer_1_reviewers).intersection(beer_2_reviewers)
print("Users in the sameset: %d"), len(common_reviewers)
list(common_reviewers)[:10]
# Out:
# Users in the sameset: %d
# ['LordAdmNelson', 'Reidrover', 'augustgarage', 'Halcyondays']

# %%
def get_beer_reviews(beer, common_users):
    mask = (df.review_profilename.isin(common_users)) & (df.beer_name==beer)
    reviews = df[mask].sort_values('review_profilename')
    reviews = reviews[reviews.review_profilename.duplicated()==False]
    return reviews
beer_1_reviews = get_beer_reviews(beer_1, common_reviewers)
beer_2_reviews = get_beer_reviews(beer_2, common_reviewers)

cols = ['beer_name', 'review_profilename', 'review_overall', 'review_aroma', 'review_palate', 'review_taste']
beer_2_reviews[cols].head()
# Out:
#               beer_name review_profilename  review_overall  review_aroma  \
# 13  Caldera Ginger Beer        Halcyondays             4.0           4.5
# 8   Caldera Ginger Beer      LordAdmNelson             4.0           3.0
# 6   Caldera Ginger Beer          Reidrover             3.5           3.5
# 9   Caldera Ginger Beer       augustgarage             4.5           3.5
#
#     review_palate  review_taste
# 13            2.5           3.0
# 8             3.5           4.0
# 6             4.0           4.0
# 9             4.0           4.0

# %% [markdown]
# ## Calculating Distance

# %%
ALL_FEATURES = ['review_overall', 'review_aroma', 'review_palate', 'review_taste', 'review_appearance']

# %%
warnings.filterwarnings("ignore")

ALL_FEATURES = ['review_overall', 'review_aroma', 'review_palate', 'review_taste']
def calculate_similarity(beer1, beer2):
    # find common reviewers
    beer_1_reviewers = df[df.beer_name==beer1].review_profilename.unique()
    beer_2_reviewers = df[df.beer_name==beer2].review_profilename.unique()
    common_reviewers = set(beer_1_reviewers).intersection(beer_2_reviewers)

    # get reviews
    beer_1_reviews = get_beer_reviews(beer1, common_reviewers)
    beer_2_reviews = get_beer_reviews(beer2, common_reviewers)
    dists = []
    for f in ALL_FEATURES:
        dists.append(euclidean_distances([beer_1_reviews[f]], [beer_2_reviews[f]])[0][0])
    return dists

calculate_similarity(beer_1, beer_2)
# Out:
# [0.8660254037844386, 1.118033988749895, 1.5, 1.3228756555322954]

# %% [markdown]
# ## Calculate the Similarity for a Set of Beers

# %%
# calculate only a subset for the demo
warnings.filterwarnings("ignore")
beers = ["Dale's Pale Ale", "Sierra Nevada Pale Ale", "Michelob Ultra",
        "Natural Light", "Bud Light", "Fat Tire Amber Ale", "Coors Light",
         "Blue Moon Belgian White", "60 Minute IPA", "Guinness Draught", "Old Rasputin Russian Imperial Stout",
         "90 Minute IPA","Sierra Nevada Celebration Ale","Two Hearted Ale","Arrogant Bastard Ale","Pliny The Elder",
         "Sierra Nevada Bigfoot Barleywine Style Ale","La Fin Du Monde","Trappistes Rochefort 10","Ayinger Celebrator Doppelbock",
         "St. Bernardus Abt 12","Imperial Stout", "Samuel Adams Boston Lager","Duvel","Dead Guy Ale","Orval Trappist Ale",
         "Weihenstephaner Hefeweissbier", "Budweiser","Samuel Smith's Oatmeal Stout","Samuel Adams Octoberfest"]

# calculate everything for real production
# beers = df.beer_name.unique()

simple_distances = []
for beer1 in beers:
    print("starting") 
    print(beer1)
    for beer2 in beers:
        if beer1 != beer2:
            row = [beer1, beer2] + calculate_similarity(beer1, beer2)
            simple_distances.append(row)
# Out:
# starting
# Dale's Pale Ale
# starting
# Sierra Nevada Pale Ale
# starting
# Michelob Ultra
# starting
# Natural Light
# starting
# Bud Light
# starting
# Fat Tire Amber Ale
# starting
# Coors Light
# starting
# Blue Moon Belgian White
# starting
# 60 Minute IPA
# starting
# Guinness Draught
# starting
# Old Rasputin Russian Imperial Stout
# starting
# 90 Minute IPA
# starting
# Sierra Nevada Celebration Ale
# starting
# Two Hearted Ale
# starting
# Arrogant Bastard Ale
# starting
# Pliny The Elder
# starting
# Sierra Nevada Bigfoot Barleywine Style Ale
# starting
# La Fin Du Monde
# starting
# Trappistes Rochefort 10
# starting
# Ayinger Celebrator Doppelbock
# starting
# St. Bernardus Abt 12
# starting
# Imperial Stout
# starting
# Samuel Adams Boston Lager
# starting
# Duvel
# starting
# Dead Guy Ale
# starting
# Orval Trappist Ale
# starting
# Weihenstephaner Hefeweissbier
# starting
# Budweiser
# starting
# Samuel Smith's Oatmeal Stout
# starting
# Samuel Adams Octoberfest

# %% [markdown]
# ## Inspect the Results

# %%
cols = ["beer1", "beer2", "overall_dist", "aroma_dist", "palate_dist", "taste_dist"]
simple_distances = pd.DataFrame(simple_distances, columns=cols)
simple_distances.tail(15)
# Out:
#                         beer1                                       beer2  \
# 855  Samuel Adams Octoberfest                        Arrogant Bastard Ale
# 856  Samuel Adams Octoberfest                             Pliny The Elder
# 857  Samuel Adams Octoberfest  Sierra Nevada Bigfoot Barleywine Style Ale
# 858  Samuel Adams Octoberfest                             La Fin Du Monde
# 859  Samuel Adams Octoberfest                     Trappistes Rochefort 10
# 860  Samuel Adams Octoberfest               Ayinger Celebrator Doppelbock
# 861  Samuel Adams Octoberfest                        St. Bernardus Abt 12
# 862  Samuel Adams Octoberfest                              Imperial Stout
# 863  Samuel Adams Octoberfest                   Samuel Adams Boston Lager
# 864  Samuel Adams Octoberfest                                       Duvel
# 865  Samuel Adams Octoberfest                                Dead Guy Ale
# 866  Samuel Adams Octoberfest                          Orval Trappist Ale
# 867  Samuel Adams Octoberfest               Weihenstephaner Hefeweissbier
# 868  Samuel Adams Octoberfest                                   Budweiser
# 869  Samuel Adams Octoberfest                Samuel Smith's Oatmeal Stout
#
#      overall_dist  aroma_dist  palate_dist  taste_dist
# 855     25.238859   28.631277    26.706741   29.189039
# 856     24.259019   30.886890    23.911294   26.893308
# 857     25.514702   29.236108    26.589472   28.879058
# 858     24.652586   29.415132    27.376998   29.449109
# 859     23.811762   30.757113    28.253318   30.020826
# 860     25.278449   28.535066    26.636441   29.736341
# 861     24.361855   29.828677    28.831406   30.095681
# 862     19.912308   22.005681    21.569655   22.242976
# 863     23.021729   21.059440    20.916501   21.430119
# 864     26.781523   27.363297    27.522718   28.827071
# 865     22.577644   21.365861    21.236761   22.869193
# 866     22.660538   26.509432    22.699119   24.413111
# 867     26.846788   29.588849    25.446021   27.897132
# 868     34.572388   36.121323    34.705907   36.221541
# 869     24.320773   25.005000    26.324893   26.962938

# %% [markdown]
# ## Allow the User to Customize the Weights

# %%
def calc_distance(dists, beer1, beer2, weights):
    mask = (dists.beer1==beer1) & (dists.beer2==beer2)
    row = dists[mask]
    row = row[['overall_dist', 'aroma_dist', 'palate_dist', 'taste_dist']]
    dist = weights * row
    return dist.sum(axis=1).tolist()[0]

weights = [2, 1, 2, 1]
#fixed from PY 2.7
print(calc_distance(simple_distances, 'Fat Tire Amber Ale', "Dale's Pale Ale", weights))
print(calc_distance(simple_distances, "Fat Tire Amber Ale", "Michelob Ultra", weights))
# Out:
# 102.95349368782318
# 182.5057726767514

# %% [markdown]
# ## Find Similar Beers

# %%
my_beer = "Samuel Smith's Oatmeal Stout"
results = []
for b in beers:
    if my_beer!=b:
        results.append((my_beer, b, calc_distance(simple_distances, my_beer, b, weights)))
sorted(results, key=lambda x: x[2])[0:4]
# Out:
# [("Samuel Smith's Oatmeal Stout", "Dale's Pale Ale", 100.03287900519081),
#  ("Samuel Smith's Oatmeal Stout", 'Pliny The Elder', 110.85382231220953),
#  ("Samuel Smith's Oatmeal Stout",
#   'Weihenstephaner Hefeweissbier',
#   116.48301840501134),
#  ("Samuel Smith's Oatmeal Stout", 'Two Hearted Ale', 120.7930670918206)]

# %% [markdown]
# # See in Production
# http://beers.yhathq.com/

# %% [markdown]
# # Similar program in R

# %% [markdown]
# http://blog.yhat.com/posts/recommender-system-in-r.html
